# %% [markdown]
# <a href="https://colab.research.google.com/github/TaoIzzo/UDLAP/blob/main/Copia_de_Ejercicio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Ejercicio 4
# ## Variables Numericas

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### 1. Crea un Histograma para la variable *petal_length*. Trata de escoger un buen numero de bins y observa el patron. Observa: ¿cuantos maximos locales existen?

# %%
plt.hist(iris.petal_length,bins=5)
plt.title("Histograma de petal length")
plt.xlabel("bins")
plt.ylabel('lenght')
plt.show()
#5 maximos locales, depende de bins

# %% [markdown]
# ### 2. Usando `seaborn`, crea un KDE plot para la misma variable. Escoge un buen bandwidth.

# %%
sns.kdeplot(iris.petal_length)
plt.title("Distribucion de petal lenght")
# Out:
# Text(0.5, 1.0, 'Distribucion de petal lenght')

# %% [markdown]
# Parecieran haber dos, o quiza, tres maximos. ¿Sera que cada uno de ellos corresponde al valor mas comun para cada uno de las distintas `species`?
#
# ### 3. Usa `sns.displot` para crear un histograma o un KDE plot. Investiga como funciona el parametro *hue* y usalo para probar lo anterior.

# %%
sns.kdeplot(data=iris)
plt.title("KDE PLOT")
# Out:
# Text(0.5, 1.0, 'KDE PLOT')

# %%
sns.histplot(data=iris)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data=iris,x="sepal_length",hue="species")
plt.title("Histograma se sepal lenght")
# Out:
# Text(0.5, 1.0, 'Histograma se sepal lenght')

# %%
sns.kdeplot(data=iris,x="sepal_length",hue="species")
plt.title("KDE PLOT")
# Out:
# Text(0.5, 1.0, 'KDE PLOT')

# %%
sns.kdeplot(data=iris,x="sepal_length",y="sepal_width",hue="species")
plt.title("KDE PLOT")
# Out:
# Text(0.5, 1.0, 'KDE PLOT')

# %% [markdown]
# ### 4. Crea un _scatterplot_ entre las variables *petal_length* y *sepal_length*. Asegurate que los ejes X y Y empiecen en 0.

# %%
plt.scatter(iris["petal_length"],	iris["sepal_length"])
plt.title("petal y sepal lenght")
plt.xlabel("petal_length")
plt.ylabel("sepal_length")
plt.xlim([0,7])
plt.ylim([0,8])
plt.show()

# %% [markdown]
# ### 5. Usa seaborn o matplotlib para crear un grafico de dispersion con las variables *petal_length* y *sepal_length*. Ahora colorea los puntos segun *species* y asegurate de incluir una leyenda.

# %%
sns.scatterplot(data=iris, x="petal_length", y="sepal_length", hue="species")
plt.title("petal y sepal lenght")
plt.xlim([0,7])
plt.ylim([0,8])
# Out:
# (0.0, 8.0)

# %% [markdown]
# ¿Notaste como una buena grafica te ayuda a ver las caracteristicas que distinguen a cada especie, sin tener que hacer un modelo?
