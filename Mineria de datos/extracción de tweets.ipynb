# %%
import tweepy
import pandas as pd

# %%
API_KEY = 'azPJfV3hvhUuNIyBvrVnW06xl'
API_SECRET_KEY = 'GhHazOPcGe3N34BvysB0ZC7ioFqHTHvdfDjag5EN52e8aKzcLN'
ACCESS_TOKEN = '4879386399-qHErUYwz0vCNiGJRfThy88PD5oAHmnYfgHr07cZ'
ACCESS_TOKEN_SECRET = 'ZsIjUtTO4NFMQ3WINbOkYpwRmsP3vCey3EbAWy805zkcR'

# %%
auth = tweepy.OAuthHandler(API_KEY, API_SECRET_KEY)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(f'{tweet.user.screen_name}:\n{tweet.text}\n{"*"*60}')
# Out:
# escritosvibes:
# RT @iComidaPerfecta: https://t.co/nN6Jhr2tcW
# ************************************************************
# los40mx:
# Claro ejemplo de que los seres humanos pueden canalizar la superfuerza en momentos de necesidad 😱
# https://t.co/tUxPjqf1Pv
# ************************************************************
# los40mx:
# ¿Tendría la necesidad de hacer algo así?
# https://t.co/EK09rxx3IB
# ************************************************************
# escritosvibes:
# RT @gessicabanks: Amo el amor de amigos. No hay interés por placer físico ni lazos de sangre. Genuinamente pasas tiempo con ellos por qué q…
# ************************************************************
# escritosvibes:
# RT @soyrebekka: La vida pasa tan rápido frente a tus ojos, que en un abrir y cerrar, estás donde siempre esperaste estar, no pierdas la fe🙌🏾
# ************************************************************
# ExaFM:
# #ExaNews Mane si deseaba ser mamá 👇
#
# https://t.co/sA6KiGQS0S
# ...

# %%
userID = "los40mx"
tweets = api.user_timeline(screen_name=userID, 
                           count=200,
                           include_rts = False)
print("Number of Tweets Extracted: {}.\n".format(len(tweets)))
# Out:
# Number of Tweets Extracted: 179.

# %%
#simple overview to make sure that it pulls correctly...
for tweet in tweets[:49]:
    print(tweet.text)
# Out:
# Claro ejemplo de que los seres humanos pueden canalizar la superfuerza en momentos de necesidad 😱
# https://t.co/tUxPjqf1Pv
# ¿Tendría la necesidad de hacer algo así?
# https://t.co/EK09rxx3IB
# Ella sabe que su equipo es parte del éxito 👏🏻 https://t.co/f3pEJPJWVr
# Afirman que los administradores aplican la normativa de forma desigual 😱
# https://t.co/xcZCtkSZHZ
# ¡Órale, güey! Regístrate, participa y gana dinero en este mes 😍 Todos los detalles te los dejamos aquí 👇
#
# https://t.co/U85jDCQ6Dd
# No hay duda que muchos se inspiraron en El Juego del Calamar para hacer algo creativo.
# https://t.co/8qMFlkIFo1
# Así habla del verdadero culpable de su divorcio https://t.co/vKURyTkcVG
# Mañana, a las 6:00 pm, podrás escuchar las buenas rolas de LP, Los Caligaris, Los Claxons, Matisse y Sofi Tukker en… https://t.co/bBN5vqoFqI
# ¿Quieres ir al #CoronaCapital? LOS40 te invita. Regístrate, participa y gana tu boleto doble 👇👇👇
#
# https://t.co/LNqzpgh3oK
# ...

# %%
ZDNET1 = pd.DataFrame(data=[[len(tweet.text), tweet.text, tweet.created_at, tweet.user.screen_name] for tweet in tweets], columns = ['Tweet_Length', 'Tweet_Text', 'Tweet_Date', 'UserName'])
ZDNET1.head(10)
# Out:
#    Tweet_Length                                         Tweet_Text  \
# 0           121  Claro ejemplo de que los seres humanos pueden ...
# 1            65  ¿Tendría la necesidad de hacer algo así? \nhtt...
# 2            69  Ella sabe que su equipo es parte del éxito 👏🏻 ...
# 3            96  Afirman que los administradores aplican la nor...
# 4           129  ¡Órale, güey! Regístrate, participa y gana din...
# 5           111  No hay duda que muchos se inspiraron en El Jue...
# 6            71  Así habla del verdadero culpable de su divorci...
# 7           140  Mañana, a las 6:00 pm, podrás escuchar las bue...
# 8           121  ¿Quieres ir al #CoronaCapital? LOS40 te invita...
# 9            89  El estelar film de ciencia ficción ya confirmó...
#
#                  Tweet_Date UserName
# 0 2021-10-28 03:00:22+00:00  los40mx
# 1 2021-10-28 03:00:22+00:00  los40mx
# 2 2021-10-28 02:00:29+00:00  los40mx
# 3 2021-10-28 01:00:31+00:00  los40mx
# 4 2021-10-28 00:40:00+00:00  los40mx
# ...
