# %%
import numpy as np
from lib_funciones_particulares2 import*
from lib_funciones_generales  import *

# %%
def I(x):
    z = 0
    return z
K = 0.8348
L = 10

Nx = 10
dx = L/Nx
T = 2
Nt = 20
dt = T/Nt

F = dt*K/dx**2

ans = solver_Fe_simple(I, K, L, dt, F,T)

u = ans[0]
x = ans[1]
t = ans[2]
CPU = ans[3]
u_array = ans[4]
print("table: ",u_array)
# print("U:",u)

nt = Nt
time = t
y_time = u_array
x_sec_min = 0
x_sec_max = L
nx = Nx
xlab = "Longitud [cm]"
ylab = "Temperatura [C]"
fig_title = "Problema de la barra"
legend = False
XYplot_profiles(nt, time, y_time, x_sec_min, x_sec_max, nx, xlab, ylab, fig_title, legend)
plt.savefig("SolverDe.png")
# Out:
# table:  [[1.00000000e+02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 5.00000000e+01]
#  [1.00000000e+02 8.34800000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 4.17400000e+00 5.00000000e+01]
#  [1.00000000e+02 1.53022179e+01 6.96891040e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   3.48445520e-01 7.65110896e+00 5.00000000e+01]
#  [1.00000000e+02 2.11535361e+01 1.85796726e+00 5.81764640e-02
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 2.90882320e-02
#   9.28983632e-01 1.05767680e+01 5.00000000e+01]
#  [1.00000000e+02 2.61248448e+01 3.31851481e+00 2.03566429e-01
#   4.85657122e-03 0.00000000e+00 2.42828561e-03 1.01783214e-01
#   1.65925741e+00 1.30624224e+01 5.00000000e+01]
#  [1.00000000e+02 3.03880703e+01 4.96235135e+00 4.47014021e-01
# ...
