# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
nodos=["a", "b", "c", "d", "f", "g", "h", "i", "j", "k", "l", "m"]
print(nodos)
G.add_nodes_from(["a", "b", "c", "d", "e", "f", "g", "h", "i", "j", "k", "l","m"])
G.add_edges_from([("a", "b"),("a", "d"), ("a", "h"),("b", "d"),("b", "e"),("b","c"),
                 ("c","f"),("d","h"),("d","i"),("e","i"),("e","j"),("e","f"),("f","j"),
                 ("f","k"),("f","g"),("g","k"),("h","i"),("h","l"),("i","j"),("i","m"),("j","m"),
                 ("k","m"),("l","m")])
plt.figure(figsize=(7,7))
nx.draw(G, with_labels = True,font_size="20", font_color = 'black',node_size=2000,node_color="red")
grado = nx.degree_centrality(G)
# print("Centralidades de grado: ")
# for vertex in grado:
#     print(str(vertex)+": " + str(grado[vertex]))
cerca = nx.closeness_centrality(G)
# print("\nCentralidad de cercanía: ")
# for vertex in cerca:
#     print(str(vertex)+": " + str(cerca[vertex]))
inter = nx.betweenness_centrality(G)
# print("\nCentralidad de intermedio: ")
# for vertex in inter:
#     print(str(vertex)+": " + str(inter[vertex]))
vector = nx.eigenvector_centrality(G)
# print("\nCentralidad de vector: ")
# for vertex in vector:
#     print(str(vertex)+": " + str(vector[vertex]))
sorted_dict = {}
sorted_keys = sorted(grado, key=grado.get)  
for x in sorted_keys:
    sorted_dict[x] = grado[x]
# print(sorted_dict)
# Out:
# ['a', 'b', 'c', 'd', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# %%
#2 Obtenga el numero de vértices y aristas.
vertice=G.number_of_nodes()
aristas=G.number_of_edges()
print("\nEl grafo tiene "+str(vertice)+" vertices y "+str(aristas)+" aristas")

#3 Calcule la densidad del grafo.
densidad=((2*aristas)/(vertice*(vertice-1)))
print("\nLa densidad del grafo es "+str(densidad))

#4 Calcule el diámetro del grafo.
print("\nEl diamentro del grafo es "+str(nx.diameter(G,usebounds=False))+"\n")

#5 Obtenga el grado de cada uno de los vértices.
x=G.degree
for i in x:
    print("El vertice "+str(i[0])+" tiene de grado: "+str(i[1]))

#6 Obtenga los vértices de grado par y de grado impar.
print(" ")
for i in x:
    if (i[1]%2==0):
        print("Es de grado par el vertice: "+str(i[0]))
    else:
        print("No es par el grado del vertice: "+str(i[0]))

# 7. Obtenga el número de ciclos de longitud 1 (si existen), los cuales sean del vértice así si mismo.
ciclos=nx.cycle_basis(G)
for i in range(len(ciclos)):  
    if(len(list(ciclos)[i]))==1:
        print("El ciclo es de 1")
        print(list(nx.find_cliques(G))[i])
    else:
        print("No hay ciclos de longitud 1")
        break
# 8. Verifique si tiene un camino de Euler.
nx.has_eulerian_path(G)
if (nx.has_eulerian_path(G)==1):
    print("\nSi tiene camino de Euler")
else:
    print("\nNo tiene camino de Euler")

 # 9. Verifique si tiene un circuito de Euler.
nx.eulerian_circuit(G)
if (nx.has_eulerian_path(G)==1):
    print("\nSi tiene circuito de Euler")
else:
    print("\nNo tiene circuito de Euler")

# 10. Obtenga el numero de cliques que tiene el grafo.
cliques=nx.graph_number_of_cliques(G)
print("\nEl numero de cliques que tiene el grafo es: " +str(cliques)+"\n")

# 11. Muestre varios ejemplos (si existen) de cliques de 2, 3 y 4 vértices.
for i in range(cliques):
    if(len(list(nx.find_cliques(G))[i]))==2:
        print("El clique es de 2")
        print(list(nx.find_cliques(G))[i])
    elif(len(list(nx.find_cliques(G))[i]))==3:
        print("El clique es de 3")
        print(list(nx.find_cliques(G))[i])
    elif(len(list(nx.find_cliques(G))[i]))==4:
        print("El clique es de 4")
        print(list(nx.find_cliques(G))[i])
    else:
        print("No se encontraron grafos de 2, 3 o 4 vertices")
# 12. Muestre un par de ejemplos de grafos isomorfos al propuesto (puede usar la librería Matplotlib).
G2=G
plt.figure(figsize=(7,7))
nx.draw(G2, with_labels = True,font_size="20", font_color = 'black',node_size=2000,node_color="blue")
vertice=G2.number_of_nodes()
aristas=G2.number_of_edges()
print("\nEl grafo tiene "+str(vertice)+" vertices y "+str(aristas)+" aristas")
x=G2.degree
for i in x:
    print("El vertice "+str(i[0])+" tiene de grado: "+str(i[1]))
densidad=((2*aristas)/(vertice*(vertice-1)))
print("\nLa densidad del grafo es "+str(densidad))
if(nx.is_isomorphic(G,G2)==1):
    print("Los grafos son isomorfos")
print("Los grafos son isomorfos debido a que es el mismo grafo pero representado de forma distinta, si se le cambia al grafo los vertices, aunque posean el mismo numero de grado, aristas y vertices dejan de ser isomorfos")
# 13. Obtenga los vértices mas aislados en el grafo (si existen). 
sorted_dict = {}
sorted_keys = sorted(grado, key=grado.get)  
for x in sorted_keys:
    sorted_dict[x] = grado[x]
lgrado=list(sorted_dict)
if(nx.number_of_isolates(G)==0):
    print("\nNo hay vertices aisalados")
else:
    print("\nHay un vertice aisaldo")
print("Dentro del grafo, los vertices mas aislados son: "+lgrado[0]+", "+lgrado[1]+" y "+lgrado[2]+"\n")

# 14. Obtenga los vértices mas populares, considerando la topología del grafo. **(Centralidad)**
print(sorted_dict)
print("Las personas que deberian de sitribuir la informacion son:  "+lgrado[-1]+" y "+lgrado[-2]+"\n")

# 15. Obtenga los vértices que pueden alcanzar a otros en el menor numero de pasos. **(Cercania)**
sorted_dict = {}
sorted_keys = sorted(cerca, key=cerca.get)  
for y in sorted_keys:
    sorted_dict[y] = cerca[y]
print(sorted_dict)
lcerca=list(sorted_dict)
print("Los vertices que pueden alcanzar a otros en menor pasos o pueden distribuir la infomracion son:  "+lcerca[-1]+" , "+lcerca[-2]+" y "+lcerca[-3]+"\n")

# 16. Obtenga aquellos vértices que son esenciales para cualquier recorrido sobre elgrafo. **(intermediacion)**
sorted_dict = {}
sorted_keys = sorted(inter, key=inter.get)  
for y in sorted_keys:
    sorted_dict[y] = inter[y]
print(sorted_dict)
linter=list(sorted_dict)
print("Los vertices que son esenciales son:  "+linter[-1]+" y "+linter[-2] )

# 17. Obtenga el grafo egocéntrico del vértice mas popular y muéstrelo de manera grafica (puede usar la librería Matplotlib).
print("\n")
egocentrico=(nx.ego_graph(G,lgrado[-1],radius=1, center=True, undirected=False, distance=None))
plt.figure(figsize=(10,10))
nx.draw(egocentrico,with_labels=True,node_color="yellow",node_size=2000)
print("\n")
# 18. Verifique si el grafo esta fuertemente conectado o no.
print("\nDebido a que el grafo es no dirigido no se puede saber si esta fuertemente concectado o no, solo se puede saber si esta conectado, es decir solo se puede ver si todos los caminos estan conectados \n")
# 19. Obtenga el camino mas corto de cada vértice contra todos los demás. Para esta parte, proponga un nuevo grafo no-dirigido a partir del anterior que cuente con pesos en las aristas.
G3 = nx.Graph()
nodos=["a", "b", "c", "d", "f", "g", "h", "i", "j", "k", "l", "m"]
print(nodos)
G3.add_nodes_from(["a", "b", "c", "d", "e", "f", "g", "h", "i", "j", "k", "l","m"])
G3.add_weighted_edges_from([("a", "b",5),("a", "d",2), ("a", "h",4),("b", "d",7),("b", "e",8),("b","c",5),
                 ("c","f",7),("d","h",3),("d","i",1),("e","i",6),("e","j",8),("e","f",2),("f","j",4),
                 ("f","k",6),("f","g",1),("g","k",7),("h","i",8),("h","l",0),("i","j",1),("i","m",6),("j","m",9),
                 ("k","m",7),("l","m",5)])
pos=nx.spring_layout (G)
plt.figure(figsize=(10,10))
nx.draw(G3,pos, with_labels=True, node_size=1000,node_color="Green")
nx.draw_networkx_edge_labels(G3, pos, font_size=10, edge_labels=nx.get_edge_attributes (G3, 'weight'))

z=0
w=0
v=0
for x in G3.nodes:
    for y in G3.nodes:
        if(x!=y):
            try:
                print("El camino mas corto del nodo: " + x + " al nodo: "+y+" es: " + str(list(nx.shortest_path(G3,x,y))))
                v=v+1
            except:
                z=z+1
        if(x==y):
            w=w+1
print("El numero de caminos totales es de "+str(v)+", se omitieron "+str(w)+" por ser caminos al mismo vertice")
# 20. Tomando en cuenta el grafo anterior, proponga un nuevo grafo no-dirigido el cual cuente con las aristas faltantes para convertirlo en un grafo completo.
complete=nx.complete_graph(G3)
plt.figure(figsize=(7,7))
nx.draw_circular(complete, with_labels = True,font_size="20", font_color = 'black',node_size=2000,node_color="orange")
# Out:
# El grafo tiene 13 vertices y 23 aristas
#
# La densidad del grafo es 0.2948717948717949
#
# El diamentro del grafo es 4
#
# El vertice a tiene de grado: 3
# El vertice b tiene de grado: 4
# El vertice c tiene de grado: 2
# El vertice d tiene de grado: 4
# El vertice e tiene de grado: 4
# El vertice f tiene de grado: 5
# El vertice g tiene de grado: 2
# El vertice h tiene de grado: 4
# El vertice i tiene de grado: 5
# El vertice j tiene de grado: 4
# El vertice k tiene de grado: 3
# El vertice l tiene de grado: 2
# El vertice m tiene de grado: 4
#
# No es par el grado del vertice: a
# Es de grado par el vertice: b
# Es de grado par el vertice: c
# Es de grado par el vertice: d
# Es de grado par el vertice: e
# No es par el grado del vertice: f
# Es de grado par el vertice: g
# Es de grado par el vertice: h
# No es par el grado del vertice: i
# Es de grado par el vertice: j
# No es par el grado del vertice: k
# Es de grado par el vertice: l
# Es de grado par el vertice: m
# ...

# %%
x=G.degree

# %%
for i in G.degree:
    print("el vertice "+str(i[0])+" tiene de grado "+str(i[1]))
# Out:
# el vertice a tiene de grado 3
# el vertice b tiene de grado 4
# el vertice c tiene de grado 2
# el vertice d tiene de grado 4
# el vertice e tiene de grado 4
# el vertice f tiene de grado 5
# el vertice g tiene de grado 2
# el vertice h tiene de grado 4
# el vertice i tiene de grado 5
# el vertice j tiene de grado 4
# el vertice k tiene de grado 3
# el vertice l tiene de grado 2
# el vertice m tiene de grado 4

# %%
sorted_dict = {}
sorted_keys = sorted(grado, key=grado.get)  
for x in sorted_keys:
    sorted_dict[x] = grado[x]
print(sorted_dict)
lgrado=list(sorted_dict)
print("\n\nLas personas que deberian de sitribuir la informacion son:  "+lgrado[-1]+" y "+lgrado[-2])
sorted_dict = {}
sorted_keys = sorted(cerca, key=cerca.get)  
for y in sorted_keys:
    sorted_dict[y] = cerca[y]
print(sorted_dict)
lcerca=list(sorted_dict)
print("las personas que deberian de sitribuir la informacion son:  "+lcerca[-1]+" y "+lcerca[-2])
sorted_dict = {}
sorted_keys = sorted(inter, key=inter.get)  
for y in sorted_keys:
    sorted_dict[y] = inter[y]
print(sorted_dict)
linter=list(sorted_dict)
print("la persona que deberian de contratar como lider es:  "+linter[-1])
if(lgrado[0]==lcerca[0]==linter[0]):
    print("basado en los calculos anteriores el candidato menos idoneo es "+str(lcerca[0]))
# Out:
# {'c': 0.16666666666666666, 'g': 0.16666666666666666, 'l': 0.16666666666666666, 'a': 0.25, 'k': 0.25, 'b': 0.3333333333333333, 'd': 0.3333333333333333, 'e': 0.3333333333333333, 'h': 0.3333333333333333, 'j': 0.3333333333333333, 'm': 0.3333333333333333, 'f': 0.41666666666666663, 'i': 0.41666666666666663}
#
#
# Las personas que deberian de sitribuir la informacion son:  i y f
# {'g': 0.3870967741935484, 'a': 0.42857142857142855, 'l': 0.42857142857142855, 'c': 0.4444444444444444, 'k': 0.46153846153846156, 'h': 0.48, 'b': 0.5, 'd': 0.5, 'f': 0.5217391304347826, 'm': 0.5217391304347826, 'e': 0.5714285714285714, 'i': 0.5714285714285714, 'j': 0.5714285714285714}
# las personas que deberian de sitribuir la informacion son:  j y i
# ...

# %%
print(lgrado)
print(lcerca)
print(linter)
# Out:
# ['c', 'g', 'l', 'a', 'k', 'b', 'd', 'e', 'h', 'j', 'm', 'f', 'i']
# ['g', 'a', 'l', 'c', 'k', 'h', 'b', 'd', 'f', 'm', 'e', 'i', 'j']
# ['g', 'a', 'l', 'c', 'd', 'k', 'j', 'h', 'e', 'b', 'm', 'i', 'f']

# %%
nx.eulerian_path(G)
if (nx.eulerian_circuit(G)==1):
    print("si")
else:
    print("no")
# Out:
# no

# %%
nx.cycle_basis(G)
# Out:
# [['f', 'k', 'g'],
#  ['i', 'h', 'l', 'm'],
#  ['a', 'd', 'h'],
#  ['i', 'd', 'h'],
#  ['a', 'b', 'd'],
#  ['f', 'c', 'b', 'd', 'h', 'l', 'm', 'k'],
#  ['i', 'e', 'b', 'd'],
#  ['j', 'e', 'b', 'd', 'h', 'l', 'm'],
#  ['f', 'e', 'b', 'd', 'h', 'l', 'm', 'k'],
#  ['f', 'j', 'm', 'k'],
#  ['i', 'j', 'm']]

# %%
len(list(nx.find_cliques(G)))
# Out:
# 13

# %%
egocentrico=(nx.ego_graph(G,lgrado[-1],radius=1, center=True, undirected=False, distance=None))
plt.figure(figsize=(10,10))
nx.draw(egocentrico,with_labels=True,node_color="yellow",node_size=2000)

# %%
(list(nx.enumerate_all_cliques(G)))
# Out:
# [['a'],
#  ['b'],
#  ['c'],
#  ['d'],
#  ['e'],
#  ['f'],
#  ['g'],
#  ['h'],
#  ['i'],
#  ['j'],
#  ['k'],
#  ['l'],
#  ['m'],
#  ['a', 'b'],
#  ['a', 'd'],
#  ['a', 'h'],
#  ['b', 'c'],
#  ['b', 'd'],
#  ['b', 'e'],
#  ['c', 'f'],
#  ['d', 'h'],
#  ['d', 'i'],
#  ['e', 'f'],
#  ['e', 'i'],
#  ['e', 'j'],
#  ['f', 'g'],
#  ['f', 'j'],
#  ['f', 'k'],
#  ['g', 'k'],
#  ['h', 'i'],
#  ['h', 'l'],
#  ['i', 'j'],
#  ['i', 'm'],
#  ['j', 'm'],
#  ['k', 'm'],
#  ['l', 'm'],
#  ['a', 'b', 'd'],
#  ['a', 'd', 'h'],
#  ['d', 'h', 'i'],
#  ['e', 'f', 'j'],
#  ['e', 'i', 'j'],
#  ['f', 'g', 'k'],
#  ['i', 'j', 'm']]

# %%
egocentrico=(nx.ego_graph(G,lgrado[-1],radius=1, center=True, undirected=False, distance=None))
plt.figure(figsize=(7,7))
plt.text(1,1,"GRAFO EGOCENTRICO")
nx.draw(egocentrico,with_labels=True)

# %%
print(len(list(nx.enumerate_all_cliques(G))))
# Out:
# 43

# %%
plt.figure(figsize=(7,7))
nx.draw_random(G, with_labels = True,font_size="20", font_color = 'black',node_size=2000,node_color="blue")

# %%
nx.is_isomorphic(G,G2)
# Out:
# True

# %%
list(nx.find_cliques(G))[1]
# Out:
# ['f', 'c']

# %%
nx.graph_number_of_cliques(G)
# Out:
# 13

# %%
(len(list(nx.find_cliques(G))[1]))==3
# Out:
# False

# %%
G2.add_edges_from([("a", "e"),("a", "d"), ("a", "f"),("b", "l"),("b", "m"),("b","i"),
                 ("b","f"),("c","k"),("c","l"),("d","e"),("d","f"),("d","g"),("e","g"),
                 ("e","i"),("f","j"),("h","j"),("h","i"),("h","k"),("h","m"),("i","m"),("j","k"),
                 ("m","j"),("i","f")])
plt.figure(figsize=(7,7))

# %%
for i in range(cliques):
    #for j in range(len(list(nx.find_cliques(G))[i])):
    #if(len(list(nx.find_cliques(G))[0]))==1:
    print(list(nx.find_cliques(G))[i])
# Out:
# ['l', 'c', 'b']
# ['l', 'm', 'b']
# ['l', 'm', 'h']
# ['f', 'c', 'b']
# ['f', 'c', 'k']
# ['f', 'k', 'g']
# ['f', 'k', 'j']
# ['f', 'e', 'j', 'i']
# ['f', 'e', 'd', 'g']
# ['f', 'e', 'd', 'b', 'a']
# ['f', 'e', 'd', 'b', 'i']
# ['h', 'a', 'd']
# ['h', 'k', 'j', 'm']

# %%
ciclos
# Out:
# [['f', 'k', 'g'],
#  ['i', 'h', 'l', 'm'],
#  ['a', 'd', 'h'],
#  ['i', 'd', 'h'],
#  ['a', 'b', 'd'],
#  ['f', 'c', 'b', 'd', 'h', 'l', 'm', 'k'],
#  ['i', 'e', 'b', 'd'],
#  ['j', 'e', 'b', 'd', 'h', 'l', 'm'],
#  ['f', 'e', 'b', 'd', 'h', 'l', 'm', 'k'],
#  ['f', 'j', 'm', 'k'],
#  ['i', 'j', 'm']]

# %%
# 7. Obtenga el número de ciclos de longitud 1 (si existen), los cuales sean del vértice así si mismo.
