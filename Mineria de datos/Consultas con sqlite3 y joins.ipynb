# %%
import pandas as pd
import sqlite3
import numpy as np

# %%
con = sqlite3.connect("C:/Users/Studio/Downloads/sourceCode/chinookdatabase/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite")
Album = pd.read_sql_query("SELECT * from Album ", con)
Artist=pd.read_sql_query("SELECT * from Artist ", con)
Customer=pd.read_sql_query("SELECT * from Customer ", con)
Employee=pd.read_sql_query("SELECT * from Employee ", con)
Genre=pd.read_sql_query("SELECT * from Genre ", con)
Invoice=pd.read_sql_query("SELECT * from Invoice ", con)
InvoiceLine=pd.read_sql_query("SELECT * from InvoiceLine ", con)
MediaType=pd.read_sql_query("SELECT * from MediaType ", con)
Playlist=pd.read_sql_query("SELECT * from Playlist ", con)
PlaylistTrack=pd.read_sql_query("SELECT * from PlaylistTrack ", con)
Track=pd.read_sql_query("SELECT * from Track ", con)

# %%
Album.isnull().sum()
# Out:
# AlbumId     0
# Title       0
# ArtistId    0
# dtype: int64

# %%
for col in Album.columns:
    print(col)
# Out:
# AlbumId
# Title
# ArtistId

# %%
Artist.isnull().sum()
# Out:
# ArtistId    0
# Name        0
# dtype: int64

# %%
Customer.isnull().sum()
# Out:
# CustomerId       0
# FirstName        0
# LastName         0
# Company         49
# Address          0
# City             0
# State           29
# Country          0
# PostalCode       4
# Phone            1
# Fax             47
# Email            0
# SupportRepId     0
# dtype: int64

# %%
Employee.isnull().sum()
# Out:
# EmployeeId    0
# LastName      0
# FirstName     0
# Title         0
# ReportsTo     1
# BirthDate     0
# HireDate      0
# Address       0
# City          0
# State         0
# Country       0
# PostalCode    0
# Phone         0
# Fax           0
# Email         0
# dtype: int64

# %%
Genre.isnull().sum()
# Out:
# GenreId    0
# Name       0
# dtype: int64

# %%
Invoice.isnull().sum()
# Out:
# InvoiceId              0
# CustomerId             0
# InvoiceDate            0
# BillingAddress         0
# BillingCity            0
# BillingState         202
# BillingCountry         0
# BillingPostalCode     28
# Total                  0
# dtype: int64

# %%
InvoiceLine.isnull().sum()
# Out:
# InvoiceLineId    0
# InvoiceId        0
# TrackId          0
# UnitPrice        0
# Quantity         0
# dtype: int64

# %%
MediaType.isnull().sum()
# Out:
# MediaTypeId    0
# Name           0
# dtype: int64

# %%
Playlist.isnull().sum()
# Out:
# PlaylistId    0
# Name          0
# dtype: int64

# %%
PlaylistTrack.isnull().sum()
# Out:
# PlaylistId    0
# TrackId       0
# dtype: int64

# %%
Track.isnull().sum()
# Out:
# TrackId           0
# Name              0
# AlbumId           0
# MediaTypeId       0
# GenreId           0
# Composer        978
# Milliseconds      0
# Bytes             0
# UnitPrice         0
# dtype: int64

# %%
Musica=Artist.join(Album.set_index('ArtistId'), on='ArtistId')
Musica
# Out:
#      ArtistId                                               Name  AlbumId  \
# 0           1                                              AC/DC      1.0
# 0           1                                              AC/DC      4.0
# 1           2                                             Accept      2.0
# 1           2                                             Accept      3.0
# 2           3                                          Aerosmith      5.0
# ..        ...                                                ...      ...
# 270       271   Mela Tenenbaum, Pro Musica Prague & Richard Kapp    342.0
# 271       272                             Emerson String Quartet    344.0
# 272       273  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...    345.0
# 273       274                                      Nash Ensemble    346.0
# 274       275                              Philip Glass Ensemble    347.0
#
#                                                  Title
# ...

# %%
d=Musica.groupby("Name").count()[["ArtistId"]].sort_values(by="ArtistId",ascending=False)
d
# Out:
#                                                     ArtistId
# Name
# Iron Maiden                                               21
# Led Zeppelin                                              14
# Deep Purple                                               11
# U2                                                        10
# Metallica                                                 10
# ...                                                      ...
# Hilary Hahn, Jeffrey Kahane, Los Angeles Chambe...         1
# House Of Pain                                              1
# Incognito                                                  1
# Instituto                                                  1
# Zeca Pagodinho                                             1
#
# [275 rows x 1 columns]

# %%
# -Artist.value_counts().sum()
Album.value_counts().sum()
# Out:
# 347

# %%
Musica.Name.value_counts()
# Out:
# Iron Maiden                  21
# Led Zeppelin                 14
# Deep Purple                  11
# Metallica                    10
# U2                           10
#                              ..
# The Police                    1
# Christopher O'Riley           1
# Wilhelm Kempff                1
# Santana Feat. Maná            1
# Scholars Baroque Ensemble     1
# Name: Name, Length: 275, dtype: int64

# %%
InvoceJ=Invoice.join(InvoiceLine.set_index('InvoiceId'), on='InvoiceId')
InvoceJ
# Out:
#      InvoiceId  CustomerId          InvoiceDate           BillingAddress  \
# 0            1           2  2009-01-01 00:00:00  Theodor-Heuss-Straße 34
# 0            1           2  2009-01-01 00:00:00  Theodor-Heuss-Straße 34
# 1            2           4  2009-01-02 00:00:00         Ullevålsveien 14
# 1            2           4  2009-01-02 00:00:00         Ullevålsveien 14
# 1            2           4  2009-01-02 00:00:00         Ullevålsveien 14
# ..         ...         ...                  ...                      ...
# 410        411          44  2013-12-14 00:00:00          Porthaninkatu 9
# 410        411          44  2013-12-14 00:00:00          Porthaninkatu 9
# 410        411          44  2013-12-14 00:00:00          Porthaninkatu 9
# 410        411          44  2013-12-14 00:00:00          Porthaninkatu 9
# 411        412          58  2013-12-22 00:00:00      12,Community Centre
#
#     BillingCity BillingState BillingCountry BillingPostalCode  Total  \
# ...

# %%
MediaType
# Out:
#    MediaTypeId                         Name
# 0            1              MPEG audio file
# 1            2     Protected AAC audio file
# 2            3  Protected MPEG-4 video file
# 3            4     Purchased AAC audio file
# 4            5               AAC audio file

# %%
PlayJ=Playlist.join(PlaylistTrack.set_index('PlaylistId'), on='PlaylistId')
PlayJ
# Out:
#     PlaylistId                 Name  TrackId
# 0            1                Music   3402.0
# 0            1                Music   3389.0
# 0            1                Music   3390.0
# 0            1                Music   3391.0
# 0            1                Music   3392.0
# ..         ...                  ...      ...
# 16          17  Heavy Metal Classic   2094.0
# 16          17  Heavy Metal Classic   2095.0
# 16          17  Heavy Metal Classic   2096.0
# 16          17  Heavy Metal Classic   3290.0
# 17          18          On-The-Go 1    597.0
#
# [8719 rows x 3 columns]

# %%
PlaylistTrack
# Out:
#       PlaylistId  TrackId
# 0              1     3402
# 1              1     3389
# 2              1     3390
# 3              1     3391
# 4              1     3392
# ...          ...      ...
# 8710          17     2094
# 8711          17     2095
# 8712          17     2096
# 8713          17     3290
# 8714          18      597
#
# [8715 rows x 2 columns]

# %%
exp=Track.join(PlaylistTrack.set_index('TrackId'),on='TrackId')
exp
# Out:
#       TrackId                                     Name  AlbumId  MediaTypeId  \
# 0           1  For Those About To Rock (We Salute You)        1            1
# 0           1  For Those About To Rock (We Salute You)        1            1
# 0           1  For Those About To Rock (We Salute You)        1            1
# 1           2                        Balls to the Wall        2            2
# 1           2                        Balls to the Wall        2            2
# ...       ...                                      ...      ...          ...
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
#
# ...

# %%
exp.join(Playlist.set_index('PlaylistId'),on='PlaylistId',rsuffix=' Playlist')
# Out:
#       TrackId                                     Name  AlbumId  MediaTypeId  \
# 0           1  For Those About To Rock (We Salute You)        1            1
# 0           1  For Those About To Rock (We Salute You)        1            1
# 0           1  For Those About To Rock (We Salute You)        1            1
# 1           2                        Balls to the Wall        2            2
# 1           2                        Balls to the Wall        2            2
# ...       ...                                      ...      ...          ...
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
# 3502     3503                            Koyaanisqatsi      347            2
#
# ...

# %%
Playlist
# Out:
#     PlaylistId                        Name
# 0            1                       Music
# 1            2                      Movies
# 2            3                    TV Shows
# 3            4                  Audiobooks
# 4            5                  90’s Music
# 5            6                  Audiobooks
# 6            7                      Movies
# 7            8                       Music
# 8            9                Music Videos
# 9           10                    TV Shows
# 10          11             Brazilian Music
# 11          12                   Classical
# 12          13   Classical 101 - Deep Cuts
# 13          14  Classical 101 - Next Steps
# 14          15  Classical 101 - The Basics
# 15          16                      Grunge
# 16          17         Heavy Metal Classic
# 17          18                 On-The-Go 1

# %%
PlaylistTrack
# Out:
#       PlaylistId  TrackId
# 0              1     3402
# 1              1     3389
# 2              1     3390
# 3              1     3391
# 4              1     3392
# ...          ...      ...
# 8710          17     2094
# 8711          17     2095
# 8712          17     2096
# 8713          17     3290
# 8714          18      597
#
# [8715 rows x 2 columns]

# %%
Track
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...
